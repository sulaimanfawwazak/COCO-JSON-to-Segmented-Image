# %%
import json
import numpy as np
import skimage
import tifffile
import os
import shutil
import random
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import cv2
from PIL import Image

# %%
from charminal import *

print(f'EMOJI_BEGIN: {EMOJI_BEGIN}')
print(f'EMOJI_ERROR: {EMOJI_ERROR}')
print(f'EMOJI_WARNING: {EMOJI_WARNING}')
print(f'EMOJI_HINT: {EMOJI_HINT}')
print(f'EMOJI_SAVING: {EMOJI_SAVING}')
print(f'EMOJI_TIME: {EMOJI_TIME}')
print(f'EMOJI_DEBUG: {EMOJI_DEBUG}')
# Out:
# EMOJI_BEGIN: 🚀
# EMOJI_ERROR: 💥
# EMOJI_WARNING: 🚨
# EMOJI_HINT: 💡
# EMOJI_SAVING: 💾
# EMOJI_TIME: ⌛
# EMOJI_DEBUG: 🔔

# %%
# Load the JSON file
base_dir = '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train'

# Read the COCO JSON segmentation file from the dataset
with open(f'{base_dir}/_annotations.coco.json', 'r') as file:
  data = json.load(file)

# %%
# Print the first 10 image filenames
for img in data['images'][:10]:
  print(img['file_name'])
# Out:
# 01605_jpeg.rf.0399606de41dae32925e6662b85ef684.jpg
# G0026625_JPG.rf.0984d2648ddd2caf60254ea473825612.jpg
# 0000085_PNG.rf.0095b22d92a65eb9ee80399fe24e4b7b.jpg
# G0026919_JPG.rf.0aa2895eeac462936d899e569c74215e.jpg
# G0026617_JPG.rf.03673452ea5193f6686b992b370fa85b.jpg
# G0026580_JPG.rf.1750af11c3c23ad1e7ea3c1f1a7cb171.jpg
# 0000183_JPG.rf.39f998130a5ffbc88a827965f7b838b0.jpg
# 01532_jpeg.rf.a235c82ebb9bd70f796accbac04f0fe3.jpg
# 0000544_PNG.rf.341ac2bfb80349af6853cd1634ee206d.jpg
# 01777_jpeg.rf.85b7d77af7accba71428e17182797479.jpg

# %%
# Print the first few filenames
for category in data['categories'][:10]:
  print(f"{category['id']}: {category['name']}")
# Out:
# 0: Aerial-Images
# 1: building
# 2: land
# 3: road
# 4: vegetated
# 5: water

# %% [markdown]
# # Understanding The Structure of COCO JSON

# %%
# Function to print the structure of the COCO JSON file
def printStructure(d, indent=0):
  spacing = '  '
  # Print the structure of a dictionary list

  # If the input is a dictionary
  if isinstance (d, dict):
    for key, value in d.items():
      print('  '*indent + str(key))
      printStructure(value, indent+1)

  # If the input is a list
  if isinstance(d, list):
    # print('  ' * indent + 'List of length {} containing:]'.format(len(d)))
    print(f'{spacing * indent}List of length {len(d)} containing:')
    if d:
      printStructure(d[0], indent+1)

# %%
printStructure(data)
# Out:
# info
#   year
#   version
#   description
#   contributor
#   url
#   date_created
# licenses
#   List of length 1 containing:]
#     id
#     url
#     name
# categories
#   List of length 6 containing:]
#     id
#     name
#     supercategory
# images
#   List of length 47 containing:]
#     id
#     license
#     file_name
#     height
#     width
#     date_captured
# annotations
#   List of length 1121 containing:]
#     id
#     image_id
#     category_id
#     bbox
#       List of length 4 containing:]
#     area
#     segmentation
#       List of length 1 containing:]
#         List of length 162 containing:]
#     iscrowd

# %%
# Colors for each classes
Building_distinct = np.asarray([255, 0, 0])
Land_distinct = np.asarray([255, 255, 0])
Road_distinct = np.asarray([0, 0, 255])
Vegetation_distinct = np.asarray([0, 255, 0])
Unlabeled_distinct = np.asarray([255, 0, 255])

# %%
from PIL import ImageColor

def decideColor(category_id):
  """
    1: building
    2: land
    3: road
    4: vegetated
    5: water
  """
  Building    = np.asarray(ImageColor.getcolor('#E09950', 'RGB'), dtype=np.uint8) # [224 153  80]
  Land        = np.asarray(ImageColor.getcolor('#F7ECCF', 'RGB'), dtype=np.uint8) # [247 236 207]
  Road        = np.asarray(ImageColor.getcolor('#B5C3D1', 'RGB'), dtype=np.uint8) # [181 195 209]
  Vegetation  = np.asarray(ImageColor.getcolor('#6FA96F', 'RGB'), dtype=np.uint8) # [111 169 111] 
  Water       = np.asarray(ImageColor.getcolor('#90DAEE', 'RGB'), dtype=np.uint8) # [144 218 238]
  Unlabeled   = np.asarray(ImageColor.getcolor('#C9AF9A', 'RGB'), dtype=np.uint8) # [253 249 239]

  if category_id == 1:
    return tuple(Building)
    # return tuple(Building_distinct)
    # return list(Building / 255.0)
  elif category_id == 2:
    return tuple(Land)
    # return tuple(Land_distinct)
    # return list(Land / 255.0)
  elif category_id == 3:
    return tuple(Road)
    # return tuple(Road_distinct)
    # return list(Road / 255.0)
  elif category_id == 4:
    return tuple(Vegetation)
    # return tuple(Vegetation_distinct)
    # return list(Vegetation / 255.0)
  else:
    print('[\U0001F6A8] Outsider detected')
    return tuple(Unlabeled)
    # return tuple(Unlabeled_distinct)

# %%
from PIL import ImageColor

def decideColorGPT(category_id):
  """
    1: building
    2: land
    3: road
    4: vegetated
    5: water
  """
  Building    = np.asarray(ImageColor.getcolor('#E09950', 'RGB')) # [224 153  80]
  Land        = np.asarray(ImageColor.getcolor('#F7ECCF', 'RGB')) # [247 236 207]
  Road        = np.asarray(ImageColor.getcolor('#B5C3D1', 'RGB')) # [181 195 209]
  Vegetation  = np.asarray(ImageColor.getcolor('#6FA96F', 'RGB')) # [111 169 111] 
  Water       = np.asarray(ImageColor.getcolor('#90DAEE', 'RGB')) # [144 218 238]
  # Unlabeled   = np.asarray(ImageColor.getcolor('#FDF9EF', 'RGB')) # [253 249 239]
  Unlabeled   = np.asarray(ImageColor.getcolor('#C9AF9A', 'RGB')) # [253 249 239]
  
  colors = {
    1: tuple(Building),
    2: tuple(Land),
    3: tuple(Road),
    4: tuple(Vegetation),
    5: tuple(Water)
  }

  return colors.get(category_id, Unlabeled)

# %%
print(decideColor(1))
# Out:
# [0.8784313725490196, 0.6, 0.3137254901960784]

# %%
Building    = np.asarray(ImageColor.getcolor('#E09950', 'RGB')) # [224 153  80]
Land        = np.asarray(ImageColor.getcolor('#F7ECCF', 'RGB')) # [247 236 207]
Road        = np.asarray(ImageColor.getcolor('#B5C3D1', 'RGB')) # [181 195 209]
Vegetation  = np.asarray(ImageColor.getcolor('#6FA96F', 'RGB')) # [111 169 111]
Water       = np.asarray(ImageColor.getcolor('#90DAEE', 'RGB')) # [144 218 238]
# Unlabeled   = np.asarray(ImageColor.getcolor('#FDF9EF', 'RGB'))[::-1] # [253 249 239]
Unlabeled   = np.asarray(ImageColor.getcolor('#C9AF9A', 'RGB')) # [253 249 239]
print(tuple(Building))
print(tuple(Land))
print(tuple(Road))
print(tuple(Vegetation))
print(tuple(Water))
print(tuple(Unlabeled))
# Out:
# (224, 153, 80)
# (247, 236, 207)
# (181, 195, 209)
# (111, 169, 111)
# (144, 218, 238)
# (201, 175, 154)

# %%
colors = {
  1: tuple(np.asarray(ImageColor.getcolor('#E09950', 'RGB'))),  # Building
  2: tuple(np.asarray(ImageColor.getcolor('#F7ECCF', 'RGB'))),  # Land
  3: tuple(np.asarray(ImageColor.getcolor('#B5C3D1', 'RGB'))),  # Road
  4: tuple(np.asarray(ImageColor.getcolor('#6FA96F', 'RGB'))),  # Vegetation
  5: tuple(np.asarray(ImageColor.getcolor('#90DAEE', 'RGB'))),  # Water
  6: tuple(np.asarray(ImageColor.getcolor('#FDF9EF', 'RGB'))),  # Unlabeled
}

# colors = {
  # 1: tuple(Building_distinct),  # Building
  # 2: tuple(Land_distinct),  # Land
  # 3: tuple(Road_distinct),  # Road
  # 4: tuple(Vegetation_distinct),  # Vegetation
  # 5: tuple(Unlabeled_distinct)  # Unlabeled
# }

def imagesWithAnnotations(image_paths, annotations, colors, output_dir):
  if not os.path.exists(output_dir):
    os.makedirs(output_dir)

  fig, axs = plt.subplots(5, 2, figsize=(30, 30))
  
  for ax, img_path in zip(axs.ravel(), image_paths):
    unlabeled_color = tuple(Unlabeled)

    # Load image using OpenCV and convert it from BGR to RGB color space
    image = cv2.imread(img_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    canvas = np.full(image.shape, unlabeled_color, dtype=np.uint8)
    
    ax.imshow(image)
    ax.axis('off')  # Turn off the axes

    # Get image filename to match with annotations
    img_filename = os.path.basename(img_path)
    img_id = next(item for item in annotations['images'] if item["file_name"] == img_filename)['id']
        
    # Filter annotations for the current image
    img_annotations = [ann for ann in annotations['annotations'] if ann['image_id'] == img_id]
        
    for ann in img_annotations:
      category_id = ann['category_id']
      # color = decideColorGPT(category_id=category_id)
      color = decideColor(category_id=category_id)

      # Display segmentation polygon
      for seg in ann['segmentation']:

        poly = np.array(seg).reshape((-1, 2))
        cv2.fillPoly(canvas, [np.int32(poly)], color=(int(color[0]), int(color[1]), int(color[2])))
    
    ax.imshow(canvas)

  plt.tight_layout()
  plt.show()

# %%
# RUN THIS (20240812)
def imagesWithAnnotations(image_paths, annotations, out_image_dir, out_mask_dir):
  if not os.path.exists(out_image_dir):
    print(f"[{EMOJI_WARNING}] {out_image_dir} doesn't exist. Creating...")
    os.makedirs(out_image_dir)

  if not os.path.exists(out_mask_dir):
    print(f"[{EMOJI_WARNING}] {out_mask_dir} doesn't exist. Creating...")
    os.makedirs(out_mask_dir)

  # fig, axs = plt.subplots(5, 2, figsize=(30, 30))

  for i, img_path in enumerate(image_paths):
    # unlabeled_color = Unlabeled_distinct
    unlabeled_color = Unlabeled

    image = cv2.imread(img_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    canvas = np.full(image.shape, unlabeled_color, dtype=np.uint8)

    img_filename = os.path.basename(img_path)
    img_id = next(item for item in annotations['images'] if item["file_name"] == img_filename)['id']
    
    img_annotations = [ann for ann in annotations['annotations'] if ann['image_id'] == img_id]

    for ann in img_annotations:
      category_id = ann['category_id']
      color = decideColor(category_id=category_id)
            
      # Display segmentation polygon
      for seg in ann['segmentation']:
        poly = np.array(seg).reshape((-1, 2))
        cv2.fillPoly(canvas, [np.int32(poly)], color=(int(color[0]), int(color[1]), int(color[2])))

    # Save the mask image
    image = Image.fromarray(image)
    canvas = Image.fromarray(canvas)

    # mask_filename = f'{img_filename}'
    mask_filename = f'{(i+20):04d}.png'
    # mask_filename = f'{mask_filename}.'
    # mask_filename = f'{img_filename[:-4]}.png'
    print(f'mask_filename: {mask_filename}')
    # print(f'{mask_filename[:-4]}.png')
    out_image_path = os.path.join(out_image_dir, mask_filename)
    out_mask_path = os.path.join(out_mask_dir, mask_filename)
    # cv2.imwrite(out_image_path, image)
    # cv2.imwrite(out_mask_path, canvas)
    image.save(out_image_path)
    canvas.save(out_mask_path)
    print(f'[{emoji_saving}] Saving image: {out_image_path}')
    print(f'[{emoji_saving}] Saving mask: {out_mask_path}')

# %%
# RUN THIS (CONT) (20240812)
all_image_files = [os.path.join(base_dir, img['file_name']) for img in data['images']]
print(all_image_files)
print(f'all_image_files len: {len(all_image_files)}')

dest_dir = '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png'

# out_image_dir = f'{base_dir}/images-png'
out_image_dir = f'{dest_dir}/images'
# out_mask_dir = f'{base_dir}/masks-png'
out_mask_dir = f'{dest_dir}/masks'
# random_image_files = random.sample(all_image_files, 10)
# display_type = 'seg'
# imagesWithAnnotations(all_image_files, data, colors, out_image_dir, out_mask_dir)
imagesWithAnnotations(all_image_files, data, out_image_dir, out_mask_dir)
# Out:
# ['/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/01605_jpeg.rf.0399606de41dae32925e6662b85ef684.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/G0026625_JPG.rf.0984d2648ddd2caf60254ea473825612.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/0000085_PNG.rf.0095b22d92a65eb9ee80399fe24e4b7b.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/G0026919_JPG.rf.0aa2895eeac462936d899e569c74215e.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/G0026617_JPG.rf.03673452ea5193f6686b992b370fa85b.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/G0026580_JPG.rf.1750af11c3c23ad1e7ea3c1f1a7cb171.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/0000183_JPG.rf.39f998130a5ffbc88a827965f7b838b0.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/01532_jpeg.rf.a235c82ebb9bd70f796accbac04f0fe3.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/0000544_PNG.rf.341ac2bfb80349af6853cd1634ee206d.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/01777_jpeg.rf.85b7d77af7accba71428e17182797479.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/0000000_PNG.rf.453852f0cc44b45f5d6f98f36ca025f5.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/G0026917_JPG.rf.2d9f0cabe5e465878554498df0b7f6ff.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/G0026661_JPG.rf.13bee3ee63393f85bbe5b7a1eeabd7be.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/01371_jpeg.rf.9ee71062f95d1a8225f9511b0476aff4.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/0000233_JPG.rf.789bb8aacde133c197786ef7d19b9372.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/01534_jpeg.rf.185b244a50ee117a9637944d0794ffb3.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/IMG_2754_JPG.rf.a0648643391bbde1627a276eeec0c272.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/G0026634_JPG.rf.7ac8813a6a9f68e92b968cf158936974.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/G0152312_JPG.rf.802b45809bfeaca358386ec2a8f16309.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/G0026631_JPG.rf.643911273b846363662069fed21759f4.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/IMG_2717_JPG.rf.9f3404ac6f999d8e59a1556e37ed9e13.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/01279_jpeg.rf.5dc2daf02632d40661912dc12f528700.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/0000208_JPG.rf.562e11eba9be9ab99019d654a27d1094.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/G0150830_JPG.rf.9548ac4690f59b363cea19dd9d3e8c12.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/G0026666_JPG.rf.8e2511fe137ba6a4336968d55a351881.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/G0026663_JPG.rf.971c38c3c19ef345672e7c05438e4947.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/G0026698_JPG.rf.2c5b7d4665651b90a3ba0f15c050bc2f.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/G0026621_JPG.rf.73839272e82fee130f8dbe13184bb0b6.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/00580_jpeg.rf.946873426dcbed701b24f996de52fe19.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/0000114_PNG.rf.60039bfbd97266c78fc107b0524ff494.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train/00592_jpeg.rf.a7b3bb1ee5b3ffe48ed8a1042f700a42.jpg', '/home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus ...
# all_image_files len: 46
# [🚨] /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images doesn't exist. Creating...
# [🚨] /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks doesn't exist. Creating...
# mask_filename: 0020.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0020.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0020.png
# mask_filename: 0021.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0021.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0021.png
# mask_filename: 0022.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0022.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0022.png
# mask_filename: 0023.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0023.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0023.png
# mask_filename: 0024.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0024.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0024.png
# mask_filename: 0025.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0025.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0025.png
# mask_filename: 0026.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0026.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0026.png
# mask_filename: 0027.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0027.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0027.png
# mask_filename: 0028.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0028.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0028.png
# mask_filename: 0029.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0029.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0029.png
# mask_filename: 0030.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0030.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0030.png
# mask_filename: 0031.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0031.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0031.png
# mask_filename: 0032.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0032.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0032.png
# mask_filename: 0033.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0033.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0033.png
# mask_filename: 0034.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0034.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0034.png
# mask_filename: 0035.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0035.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0035.png
# mask_filename: 0036.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0036.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0036.png
# mask_filename: 0037.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0037.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0037.png
# mask_filename: 0038.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0038.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0038.png
# mask_filename: 0039.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0039.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0039.png
# [🚨] Outsider detected
# mask_filename: 0040.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0040.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0040.png
# mask_filename: 0041.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0041.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0041.png
# mask_filename: 0042.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0042.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0042.png
# mask_filename: 0043.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0043.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0043.png
# mask_filename: 0044.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0044.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0044.png
# mask_filename: 0045.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0045.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0045.png
# mask_filename: 0046.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0046.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0046.png
# mask_filename: 0047.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0047.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0047.png
# mask_filename: 0048.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0048.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0048.png
# mask_filename: 0049.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0049.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0049.png
# mask_filename: 0050.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0050.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0050.png
# mask_filename: 0051.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0051.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0051.png
# mask_filename: 0052.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0052.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0052.png
# mask_filename: 0053.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0053.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0053.png
# mask_filename: 0054.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0054.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0054.png
# mask_filename: 0055.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0055.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0055.png
# mask_filename: 0056.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0056.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0056.png
# mask_filename: 0057.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0057.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0057.png
# mask_filename: 0058.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0058.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0058.png
# mask_filename: 0059.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0059.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0059.png
# mask_filename: 0060.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0060.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0060.png
# mask_filename: 0061.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0061.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0061.png
# mask_filename: 0062.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0062.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0062.png
# mask_filename: 0063.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0063.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0063.png
# mask_filename: 0064.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0064.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0064.png
# mask_filename: 0065.png
# [💾] Saving image: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/images/0065.png
# [💾] Saving mask: /home/pwnwas/Personal/Gamaforce/dataset/roboflow-plus-gading-coco/train-png/masks/0065.png
